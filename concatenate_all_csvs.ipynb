# %%
import pandas as pd
import os

# Directory containing the data files
data_directory = '/Users/sirvartsarafian/Bikes/Data/All Data'

# List all files in the directory ending with '.csv'
data_files = [file for file in os.listdir(data_directory) if file.endswith('.csv')]

# Create empty lists to store NaN counts, DataFrames for each CSV file, and datetime conversion results
NaN_counts_per_file = []
dfs = []
datetime_conversion_results = []

# Define common column names as they vary in CSVs
common_columns = ['Trip Duration', 'Start Time', 'Stop Time', 'Start Station ID', 
                  'Start Station Name', 'Start Station Latitude', 'Start Station Longitude', 
                  'End Station ID', 'End Station Name', 'End Station Latitude', 
                  'End Station Longitude', 'Bike ID', 'User Type', 'Birth Year', 'Gender']

# Loop through each data file and read it into a DataFrame
for data_file in data_files:
    # Read the CSV file into a DataFrame
    df = pd.read_csv(os.path.join(data_directory, data_file))
    
    # Rename columns to the common set of column names
    df.columns = common_columns
    
    # Convert 'Start Time' and 'Stop Time' columns to datetime format
    df['Start Time'] = pd.to_datetime(df['Start Time'], errors='coerce')
    df['Stop Time'] = pd.to_datetime(df['Stop Time'], errors='coerce')
    
    # Check if datetime conversion was successful
    conversion_result = df[['Start Time', 'Stop Time']].dtypes
    datetime_conversion_results.append(conversion_result)
    
    # Count NaN values in each column
    NaN_counts = df.isna().sum()
    NaN_counts_per_file.append(NaN_counts)
    
    # Append the DataFrame to the list
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
data = pd.concat(dfs, ignore_index=True)

# Count NaN values in each column of the concatenated DataFrame
total_NaN_counts = data.isna().sum()

# Display NaN counts for each column in each file
for i, data_file in enumerate(data_files):
    print(f"NaN counts for {data_file}:")
    print(NaN_counts_per_file[i])
    print()

# Display datetime conversion results for each file
for i, data_file in enumerate(data_files):
    print(f"Datetime conversion results for {data_file}:")
    print(datetime_conversion_results[i])
    print()

# Display total NaN counts for each column in the concatenated DataFrame
print("Total NaN counts after concatenation:")
print(total_NaN_counts)
# Out:
# NaN counts for JC-201701-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                   18
# Birth Year                 386
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201902-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201512-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                    0
# Birth Year                 720
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201801-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201709-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2384
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201809-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-20161-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                    0
# Birth Year                 302
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201510-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2297
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201803-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201703-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                   33
# Birth Year                 504
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201708 citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2669
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201908-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-20163-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                   12
# Birth Year                 890
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201608-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                    54
# Birth Year                 3432
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201606-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     4
# Birth Year                 2105
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201705-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 1943
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201610-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                    50
# Birth Year                 1785
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201910-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201805-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201906-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201912-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201811-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201807-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201904-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201604-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                    31
# Birth Year                 1749
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201707-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2960
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201711-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                    0
# Birth Year                 847
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201612-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                   41
# Birth Year                 613
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201808-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201903-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-20162-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                    0
# Birth Year                 330
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201909-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201609-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                   125
# Birth Year                 2715
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201511-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 1235
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201901-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201802-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201702-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                   66
# Birth Year                 815
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201712-citibike-tripdata.csv:
# Trip Duration                0
# Start Time                   0
# Stop Time                    0
# Start Station ID             0
# Start Station Name           0
# Start Station Latitude       0
# Start Station Longitude      0
# End Station ID               0
# End Station Name             0
# End Station Latitude         0
# End Station Longitude        0
# Bike ID                      0
# User Type                    0
# Birth Year                 450
# Gender                       0
# dtype: int64
#
# NaN counts for JC-201611-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                    49
# Birth Year                 1161
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201607-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     6
# Birth Year                 2191
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201704-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 1973
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201804-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201907-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201911-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201812-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201509-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 1376
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201806-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201905-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201810-citibike-tripdata.csv:
# Trip Duration              0
# Start Time                 0
# Stop Time                  0
# Start Station ID           0
# Start Station Name         0
# Start Station Latitude     0
# Start Station Longitude    0
# End Station ID             0
# End Station Name           0
# End Station Latitude       0
# End Station Longitude      0
# Bike ID                    0
# User Type                  0
# Birth Year                 0
# Gender                     0
# dtype: int64
#
# NaN counts for JC-201710-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2158
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201605-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     8
# Birth Year                 1726
# Gender                        0
# dtype: int64
#
# NaN counts for JC-201706-citibike-tripdata.csv:
# Trip Duration                 0
# Start Time                    0
# Stop Time                     0
# Start Station ID              0
# Start Station Name            0
# Start Station Latitude        0
# Start Station Longitude       0
# End Station ID                0
# End Station Name              0
# End Station Latitude          0
# End Station Longitude         0
# Bike ID                       0
# User Type                     0
# Birth Year                 2526
# Gender                        0
# dtype: int64
#
# Datetime conversion results for JC-201701-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201902-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201512-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201801-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201709-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201809-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-20161-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201510-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201803-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201703-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201708 citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201908-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-20163-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201608-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201606-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201705-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201610-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201910-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201805-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201906-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201912-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201811-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201807-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201904-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201604-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201707-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201711-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201612-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201808-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201903-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-20162-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201909-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201609-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201511-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201901-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201802-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201702-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201712-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201611-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201607-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201704-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201804-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201907-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201911-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201812-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201509-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201806-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201905-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201810-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201710-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201605-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Datetime conversion results for JC-201706-citibike-tripdata.csv:
# Start Time    datetime64[ns]
# Stop Time     datetime64[ns]
# dtype: object
#
# Total NaN counts after concatenation:
# Trip Duration                  0
# Start Time                     0
# Stop Time                      0
# Start Station ID               0
# Start Station Name             0
# Start Station Latitude         0
# Start Station Longitude        0
# End Station ID                 0
# End Station Name               0
# End Station Latitude           0
# End Station Longitude          0
# Bike ID                        0
# User Type                    497
# Birth Year                 44242
# Gender                         0
# dtype: int64

# %%
# Add extra columns for Year, Month, Day of Week, Date, Day of Week Name and Hour data belongs so
data['Year'] = data['Start Time'].dt.year
data['Month'] = data['Start Time'].dt.month
data['Day_of_Week'] = data['Start Time'].dt.dayofweek
data['Date'] = data['Start Time'].dt.date
data['Day of Week Name'] = data['Start Time'].dt.strftime('%A')
data['Hour'] = data['Start Time'].dt.hour

# %%
NaNs_exist = data.isna().any()

# Displaying columns containing NaT values
if NaNs_exist.any():
    print("Columns with NaT values:")
    print(NaNs_exist[NaNs_exist])
else:
    print("No NaT values found in the DataFrame.")
# Out:
# Columns with NaT values:
# User Type     True
# Birth Year    True
# dtype: bool

# %%
# Define the file to save CSV file
output_file = '/Users/sirvartsarafian/Bikes/Data/all_data.csv'  

# Save the DataFrame to a CSV file
data.to_csv(output_file, index=False)

# %%
data.head()
# Out:
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            148 2017-01-01 00:21:32 2017-01-01 00:24:01              3276
# 1           1283 2017-01-01 00:24:35 2017-01-01 00:45:58              3183
# 2            372 2017-01-01 00:38:19 2017-01-01 00:44:31              3183
# 3           1513 2017-01-01 00:38:37 2017-01-01 01:03:50              3194
# 4            639 2017-01-01 01:47:52 2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  ...  Bike ID  \
# 0            3185            City Hall             40.717732  ...    24575
# 1            3198     Heights Elevator             40.748716  ...    24723
# 2            3211           Newark Ave             40.721525  ...    24620
# 3            3271  Danforth Light Rail             40.692640  ...    24668
# 4            3203        Hamilton Park             40.727596  ...    26167
#
#     User Type Birth Year  Gender  Year  Month  Day_of_Week        Date  \
# 0  Subscriber     1983.0       1  2017      1            6  2017-01-01
# 1  Subscriber     1978.0       1  2017      1            6  2017-01-01
# 2  Subscriber     1989.0       1  2017      1            6  2017-01-01
# 3  Subscriber     1961.0       1  2017      1            6  2017-01-01
# 4  Subscriber     1993.0       1  2017      1            6  2017-01-01
#
#   Day of Week Name Hour
# 0           Sunday    0
# 1           Sunday    0
# 2           Sunday    0
# 3           Sunday    0
# 4           Sunday    1
#
# [5 rows x 21 columns]

# %%
data.tail()
# Out:
#          Trip Duration          Start Time           Stop Time  \
# 1354229            934 2017-06-30 23:50:05 2017-07-01 00:05:40
# 1354230            908 2017-06-30 23:50:31 2017-07-01 00:05:39
# 1354231            238 2017-06-30 23:52:16 2017-06-30 23:56:15
# 1354232            184 2017-06-30 23:57:50 2017-07-01 00:00:54
# 1354233            463 2017-06-30 23:59:16 2017-07-01 00:07:00
#
#          Start Station ID Start Station Name  Start Station Latitude  \
# 1354229              3211         Newark Ave               40.721525
# 1354230              3211         Newark Ave               40.721525
# 1354231              3203      Hamilton Park               40.727596
# 1354232              3267       Morris Canal               40.712419
# 1354233              3202       Newport PATH               40.727224
#
#          Start Station Longitude  End Station ID End Station Name  \
# 1354229               -74.046305            3207      Oakland Ave
# 1354230               -74.046305            3207      Oakland Ave
# 1354231               -74.044247            3211       Newark Ave
# 1354232               -74.038526            3183   Exchange Place
# 1354233               -74.033759            3203    Hamilton Park
#
#          End Station Latitude  ...  Bike ID   User Type Birth Year  Gender  \
# 1354229             40.737604  ...    26287  Subscriber     1991.0       1
# 1354230             40.737604  ...    29472  Subscriber     1993.0       2
# 1354231             40.721525  ...    29572  Subscriber     1992.0       1
# 1354232             40.716247  ...    29199  Subscriber     1985.0       1
# 1354233             40.727596  ...    26289  Subscriber     1965.0       1
#
#          Year  Month  Day_of_Week        Date Day of Week Name Hour
# 1354229  2017      6            4  2017-06-30           Friday   23
# 1354230  2017      6            4  2017-06-30           Friday   23
# 1354231  2017      6            4  2017-06-30           Friday   23
# 1354232  2017      6            4  2017-06-30           Friday   23
# 1354233  2017      6            4  2017-06-30           Friday   23
#
# [5 rows x 21 columns]

# %%
data['Hour'] = data['Start Time'].dt.hour

# %%
data.head()
# Out:
#    Trip Duration          Start Time           Stop Time  Start Station ID  \
# 0            148 2017-01-01 00:21:32 2017-01-01 00:24:01              3276
# 1           1283 2017-01-01 00:24:35 2017-01-01 00:45:58              3183
# 2            372 2017-01-01 00:38:19 2017-01-01 00:44:31              3183
# 3           1513 2017-01-01 00:38:37 2017-01-01 01:03:50              3194
# 4            639 2017-01-01 01:47:52 2017-01-01 01:58:31              3183
#
#   Start Station Name  Start Station Latitude  Start Station Longitude  \
# 0   Marin Light Rail               40.714584               -74.042817
# 1     Exchange Place               40.716247               -74.033459
# 2     Exchange Place               40.716247               -74.033459
# 3    McGinley Square               40.725340               -74.067622
# 4     Exchange Place               40.716247               -74.033459
#
#    End Station ID     End Station Name  End Station Latitude  ...  Bike ID  \
# 0            3185            City Hall             40.717732  ...    24575
# 1            3198     Heights Elevator             40.748716  ...    24723
# 2            3211           Newark Ave             40.721525  ...    24620
# 3            3271  Danforth Light Rail             40.692640  ...    24668
# 4            3203        Hamilton Park             40.727596  ...    26167
#
#     User Type Birth Year  Gender  Year  Month  Day_of_Week        Date  \
# 0  Subscriber     1983.0       1  2017      1            6  2017-01-01
# 1  Subscriber     1978.0       1  2017      1            6  2017-01-01
# 2  Subscriber     1989.0       1  2017      1            6  2017-01-01
# 3  Subscriber     1961.0       1  2017      1            6  2017-01-01
# 4  Subscriber     1993.0       1  2017      1            6  2017-01-01
#
#   Day of Week Name Hour
# 0           Sunday    0
# 1           Sunday    0
# 2           Sunday    0
# 3           Sunday    0
# 4           Sunday    1
#
# [5 rows x 21 columns]
